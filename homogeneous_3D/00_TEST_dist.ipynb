# %%
import numpy as np
import matplotlib.pyplot as plt

noise = 25
test_values =  noise * np.random.normal(0, 0.25, 10000)
test_values_2 = np.random.normal(0,25,10000)

plt.hist(test_values)
plt.show()
plt.hist(test_values_2)
plt.show()
